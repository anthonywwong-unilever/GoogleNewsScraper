# %%
from scraper.config.metadata import Theme
from scraper.news.google_news_scraper import GoogleNewsScraper
from scraper.news.article_parser import ArticleParser

import pandas as pd
import numpy as np

# %% [markdown]
# # Scrape and Parse

# %%
theme = Theme.DEMAND
keyword = "Vegetable oils used in biodiesel production demand"

urls = [
    'https://www.fas.usda.gov/data/us-renewable-diesel-production-growth-drastically-impacts-global-feedstock-trade',
    'https://www.cmegroup.com/education/articles-and-reports/increasing-volatility-drives-increased-opportunities-for-hedging-in-waste-oils.html',
    'https://www.reuters.com/markets/commodities/world-food-commodity-prices-fall-january-sugar-vegetable-oils-decline-fao-2025-02-07/',
    'https://www.cmegroup.com/articles/2022/low-carbon-fuels-drive-vegetable-oil-price-volatility.html',
    'https://www.fastmarkets.com/insights/uco-prices-reach-two-year-high-in-2024-increases-to-continue-in-2025-amid-demand/',
    'https://www.gminsights.com/industry-analysis/used-cooking-oil-market'
]

searched_articles = GoogleNewsScraper().get_search_articles(theme, keyword, urls)
articles = [article for article in searched_articles]
articles_df = ArticleParser(articles).tabulate_articles()
# Out:
# 2025-02-24 11:31:34,731 - GoogleNewsScraper - INFO - Opening Edge browser
# 2025-02-24 11:31:43,345 - GoogleNewsScraper - INFO - Waiting for page to complete loading (maximum 120 seconds)
# 2025-02-24 11:31:43,445 - GoogleNewsScraper - INFO - Navigating to the Google news article URL -> https://www.fas.usda.gov/data/us-renewable-diesel-production-growth-drastically-impacts-global-feedstock-trade
# 2025-02-24 11:31:47,870 - GoogleNewsScraper - INFO - Waiting for page to complete loading (maximum 120 seconds)
# 2025-02-24 11:31:47,922 - GoogleNewsScraper - INFO - Waiting for the article URL domain to change from "news.google.com" to its original domain
# 2025-02-24 11:31:47,939 - GoogleNewsScraper - INFO - Getting the article's site name, domain URL, and HTML content from https://www.fas.usda.gov/data/us-renewable-diesel-production-growth-drastically-impacts-global-feedstock-trade
# 2025-02-24 11:31:48,009 - GoogleNewsScraper - INFO - Article info successfully scraped from https://www.fas.usda.gov/data/us-renewable-diesel-production-growth-drastically-impacts-global-feedstock-trade
#
# 2025-02-24 11:31:48,035 - GoogleNewsScraper - INFO - Navigating to the Google news article URL -> https://www.cmegroup.com/education/articles-and-reports/increasing-volatility-drives-increased-opportunities-for-hedging-in-waste-oils.html
# 2025-02-24 11:31:58,667 - GoogleNewsScraper - INFO - Waiting for page to complete loading (maximum 120 seconds)
# 2025-02-24 11:31:58,738 - GoogleNewsScraper - INFO - Waiting for the article URL domain to change from "news.google.com" to its original domain
# 2025-02-24 11:31:58,836 - GoogleNewsScraper - INFO - Getting the article's site name, domain URL, and HTML content from https://www.cmegroup.com/education/articles-and-reports/increasing-volatility-drives-increased-opportunities-for-hedging-in-waste-oils.html
# 2025-02-24 11:31:59,086 - GoogleNewsScraper - INFO - Article info successfully scraped from https://www.cmegroup.com/education/articles-and-reports/increasing-volatility-drives-increased-opportunities-for-hedging-in-waste-oils.html
#
# 2025-02-24 11:31:59,368 - GoogleNewsScraper - INFO - Navigating to the Google news article URL -> https://www.reuters.com/markets/commodities/world-food-commodity-prices-fall-january-sugar-vegetable-oils-decline-fao-2025-02-07/
# 2025-02-24 11:32:37,706 - GoogleNewsScraper - INFO - Waiting for page to complete loading (maximum 120 seconds)
# 2025-02-24 11:32:37,913 - GoogleNewsScraper - INFO - Waiting for the article URL domain to change from "news.google.com" to its original domain
# 2025-02-24 11:32:37,932 - GoogleNewsScraper - INFO - Getting the article's site name, domain URL, and HTML content from https://www.reuters.com/markets/commodities/world-food-commodity-prices-fall-january-sugar-vegetable-oils-decline-fao-2025-02-07/
# 2025-02-24 11:32:38,266 - GoogleNewsScraper - INFO - Article info successfully scraped from https://www.reuters.com/markets/commodities/world-food-commodity-prices-fall-january-sugar-vegetable-oils-decline-fao-2025-02-07/
#
# 2025-02-24 11:32:38,302 - GoogleNewsScraper - INFO - Navigating to the Google news article URL -> https://www.cmegroup.com/articles/2022/low-carbon-fuels-drive-vegetable-oil-price-volatility.html
# 2025-02-24 11:32:47,027 - GoogleNewsScraper - INFO - Waiting for page to complete loading (maximum 120 seconds)
# 2025-02-24 11:32:47,119 - GoogleNewsScraper - INFO - Waiting for the article URL domain to change from "news.google.com" to its original domain
# 2025-02-24 11:32:47,142 - GoogleNewsScraper - INFO - Getting the article's site name, domain URL, and HTML content from https://www.cmegroup.com/articles/2022/low-carbon-fuels-drive-vegetable-oil-price-volatility.html
# 2025-02-24 11:32:47,434 - GoogleNewsScraper - INFO - Article info successfully scraped from https://www.cmegroup.com/articles/2022/low-carbon-fuels-drive-vegetable-oil-price-volatility.html
#
# 2025-02-24 11:32:47,551 - GoogleNewsScraper - INFO - Navigating to the Google news article URL -> https://www.fastmarkets.com/insights/uco-prices-reach-two-year-high-in-2024-increases-to-continue-in-2025-amid-demand/
# 2025-02-24 11:32:52,207 - GoogleNewsScraper - INFO - Waiting for page to complete loading (maximum 120 seconds)
# 2025-02-24 11:32:52,245 - GoogleNewsScraper - INFO - Waiting for the article URL domain to change from "news.google.com" to its original domain
# 2025-02-24 11:32:52,292 - GoogleNewsScraper - INFO - Getting the article's site name, domain URL, and HTML content from https://www.fastmarkets.com/insights/uco-prices-reach-two-year-high-in-2024-increases-to-continue-in-2025-amid-demand/
# 2025-02-24 11:32:52,458 - GoogleNewsScraper - INFO - Article info successfully scraped from https://www.fastmarkets.com/insights/uco-prices-reach-two-year-high-in-2024-increases-to-continue-in-2025-amid-demand/
#
# 2025-02-24 11:32:52,506 - GoogleNewsScraper - INFO - Navigating to the Google news article URL -> https://www.gminsights.com/industry-analysis/used-cooking-oil-market
# 2025-02-24 11:32:55,610 - GoogleNewsScraper - INFO - Waiting for page to complete loading (maximum 120 seconds)
# 2025-02-24 11:32:59,445 - GoogleNewsScraper - INFO - Waiting for the article URL domain to change from "news.google.com" to its original domain
# 2025-02-24 11:32:59,468 - GoogleNewsScraper - INFO - Getting the article's site name, domain URL, and HTML content from https://www.gminsights.com/industry-analysis/used-cooking-oil-market
# 2025-02-24 11:32:59,560 - GoogleNewsScraper - INFO - Article info successfully scraped from https://www.gminsights.com/industry-analysis/used-cooking-oil-market
#
# 2025-02-24 11:32:59,562 - ArticleParser - INFO - Begin parsing the article -> "USDA Foreign Agricultural Service": https://www.fas.usda.gov/data/us-renewable-diesel-production-growth-drastically-impacts-global-feedstock-trade
# 2025-02-24 11:32:59,564 - ArticleParser - INFO - Checking if there's instructions available for parsing articles from "USDA Foreign Agricultural Service"
# 2025-02-24 11:32:59,565 - ArticleParser - INFO - Instruction available for "USDA Foreign Agricultural Service"
# 2025-02-24 11:32:59,566 - ArticleParser - INFO - Checking if the instruction for parsing articles from "USDA Foreign Agricultural Service" is in scope
# 2025-02-24 11:32:59,568 - ArticleParser - INFO - Instruction in scope for "USDA Foreign Agricultural Service"
# 2025-02-24 11:32:59,580 - ArticleParser - INFO - Parsing the article's title using CSS
# 2025-02-24 11:32:59,583 - ArticleParser - ERROR - No info parsed for article's title. Either no info present or need to add a new instruction under "USDA Foreign Agricultural Service"
# 2025-02-24 11:32:59,586 - ArticleParser - INFO - Parsing the article's date using CSS
# 2025-02-24 11:32:59,590 - ArticleParser - ERROR - No info parsed for article's date. Either no info present or need to add a new instruction under "USDA Foreign Agricultural Service"
# 2025-02-24 11:32:59,591 - ArticleParser - INFO - Parsing the article's author using CSS
# 2025-02-24 11:32:59,595 - ArticleParser - INFO - Successfully parsed the article's author info
# 2025-02-24 11:32:59,605 - ArticleParser - INFO - Successfully parsed the article's content info
# 2025-02-24 11:32:59,607 - ArticleParser - INFO - Finish parsing the article -> "USDA Foreign Agricultural Service": https://www.fas.usda.gov/data/us-renewable-diesel-production-growth-drastically-impacts-global-feedstock-trade
#
# 2025-02-24 11:32:59,608 - ArticleParser - INFO - Begin parsing the article -> "CME Group": https://www.cmegroup.com/education/articles-and-reports/increasing-volatility-drives-increased-opportunities-for-hedging-in-waste-oils.html
# 2025-02-24 11:32:59,610 - ArticleParser - INFO - Checking if there's instructions available for parsing articles from "CME Group"
# 2025-02-24 11:32:59,611 - ArticleParser - INFO - Instruction available for "CME Group"
# 2025-02-24 11:32:59,613 - ArticleParser - INFO - Checking if the instruction for parsing articles from "CME Group" is in scope
# 2025-02-24 11:32:59,614 - ArticleParser - INFO - Instruction in scope for "CME Group"
# 2025-02-24 11:32:59,653 - ArticleParser - INFO - Parsing the article's title using CSS
# 2025-02-24 11:32:59,657 - ArticleParser - ERROR - No info parsed for article's title. Either no info present or need to add a new instruction under "CME Group"
# 2025-02-24 11:32:59,662 - ArticleParser - INFO - Parsing the article's date using CSS
# 2025-02-24 11:32:59,666 - ArticleParser - ERROR - No info parsed for article's date. Either no info present or need to add a new instruction under "CME Group"
# 2025-02-24 11:32:59,669 - ArticleParser - INFO - Parsing the article's author using CSS
# 2025-02-24 11:32:59,676 - ArticleParser - ERROR - No info parsed for article's author. Either no info present or need to add a new instruction under "CME Group"
# 2025-02-24 11:32:59,681 - ArticleParser - ERROR - No info parsed for article's content. Either no info present or need to add a new instruction under "CME Group"
# 2025-02-24 11:32:59,684 - ArticleParser - INFO - Finish parsing the article -> "CME Group": https://www.cmegroup.com/education/articles-and-reports/increasing-volatility-drives-increased-opportunities-for-hedging-in-waste-oils.html
#
# 2025-02-24 11:32:59,687 - ArticleParser - INFO - Begin parsing the article -> "Reuters": https://www.reuters.com/markets/commodities/world-food-commodity-prices-fall-january-sugar-vegetable-oils-decline-fao-2025-02-07/
# 2025-02-24 11:32:59,694 - ArticleParser - INFO - Checking if there's instructions available for parsing articles from "Reuters"
# 2025-02-24 11:32:59,730 - ArticleParser - INFO - Instruction available for "Reuters"
# 2025-02-24 11:32:59,733 - ArticleParser - INFO - Checking if the instruction for parsing articles from "Reuters" is in scope
# 2025-02-24 11:32:59,736 - ArticleParser - INFO - Instruction in scope for "Reuters"
# 2025-02-24 11:32:59,780 - ArticleParser - INFO - Finish parsing the article -> "Reuters": https://www.reuters.com/markets/commodities/world-food-commodity-prices-fall-january-sugar-vegetable-oils-decline-fao-2025-02-07/
#
# 2025-02-24 11:32:59,795 - ArticleParser - INFO - Begin parsing the article -> "CME Group": https://www.cmegroup.com/articles/2022/low-carbon-fuels-drive-vegetable-oil-price-volatility.html
# 2025-02-24 11:32:59,810 - ArticleParser - INFO - Checking if there's instructions available for parsing articles from "CME Group"
# 2025-02-24 11:32:59,862 - ArticleParser - INFO - Instruction available for "CME Group"
# 2025-02-24 11:32:59,864 - ArticleParser - INFO - Checking if the instruction for parsing articles from "CME Group" is in scope
# 2025-02-24 11:32:59,868 - ArticleParser - INFO - Instruction in scope for "CME Group"
# 2025-02-24 11:32:59,895 - ArticleParser - INFO - Parsing the article's title using CSS
# 2025-02-24 11:32:59,901 - ArticleParser - INFO - Successfully parsed the article's title info
# 2025-02-24 11:32:59,905 - ArticleParser - INFO - Parsing the article's date using CSS
# 2025-02-24 11:32:59,910 - ArticleParser - INFO - Successfully parsed the article's date info
# 2025-02-24 11:32:59,913 - ArticleParser - INFO - Parsing the article's author using CSS
# 2025-02-24 11:32:59,921 - ArticleParser - INFO - Successfully parsed the article's author info
# 2025-02-24 11:33:00,008 - ArticleParser - INFO - Successfully parsed the article's content info
# 2025-02-24 11:33:00,013 - ArticleParser - INFO - Finish parsing the article -> "CME Group": https://www.cmegroup.com/articles/2022/low-carbon-fuels-drive-vegetable-oil-price-volatility.html
#
# 2025-02-24 11:33:00,016 - ArticleParser - INFO - Begin parsing the article -> "Fastmarkets": https://www.fastmarkets.com/insights/uco-prices-reach-two-year-high-in-2024-increases-to-continue-in-2025-amid-demand/
# 2025-02-24 11:33:00,020 - ArticleParser - INFO - Checking if there's instructions available for parsing articles from "Fastmarkets"
# 2025-02-24 11:33:00,022 - ArticleParser - INFO - Instruction available for "Fastmarkets"
# 2025-02-24 11:33:00,025 - ArticleParser - INFO - Checking if the instruction for parsing articles from "Fastmarkets" is in scope
# 2025-02-24 11:33:00,034 - ArticleParser - INFO - Instruction in scope for "Fastmarkets"
# 2025-02-24 11:33:00,053 - ArticleParser - INFO - Parsing the article's title using CSS
# 2025-02-24 11:33:00,058 - ArticleParser - INFO - Successfully parsed the article's title info
# 2025-02-24 11:33:00,061 - ArticleParser - INFO - Parsing the article's date using CSS
# 2025-02-24 11:33:00,064 - ArticleParser - INFO - Successfully parsed the article's date info
# 2025-02-24 11:33:00,066 - ArticleParser - INFO - Parsing the article's author using CSS
# 2025-02-24 11:33:00,091 - ArticleParser - INFO - Successfully parsed the article's author info
# 2025-02-24 11:33:00,097 - ArticleParser - INFO - Successfully parsed the article's content info
# 2025-02-24 11:33:00,099 - ArticleParser - INFO - Finish parsing the article -> "Fastmarkets": https://www.fastmarkets.com/insights/uco-prices-reach-two-year-high-in-2024-increases-to-continue-in-2025-amid-demand/
#
# 2025-02-24 11:33:00,103 - ArticleParser - INFO - Begin parsing the article -> "Global Market Insights (GMI)": https://www.gminsights.com/industry-analysis/used-cooking-oil-market
# 2025-02-24 11:33:00,105 - ArticleParser - INFO - Checking if there's instructions available for parsing articles from "Global Market Insights (GMI)"
# 2025-02-24 11:33:00,108 - ArticleParser - INFO - Instruction available for "Global Market Insights (GMI)"
# 2025-02-24 11:33:00,115 - ArticleParser - INFO - Checking if the instruction for parsing articles from "Global Market Insights (GMI)" is in scope
# 2025-02-24 11:33:00,117 - ArticleParser - INFO - Instruction in scope for "Global Market Insights (GMI)"
# 2025-02-24 11:33:00,134 - ArticleParser - INFO - Finish parsing the article -> "Global Market Insights (GMI)": https://www.gminsights.com/industry-analysis/used-cooking-oil-market

# %% [markdown]
# # All Articles

# %%
articles_df
# Out:
#                                 site  \
# 0  USDA Foreign Agricultural Service
# 1                          CME Group
# 2                            Reuters
# 3                          CME Group
# 4                        Fastmarkets
# 5       Global Market Insights (GMI)
#
#                                                  url   theme  \
# 0  https://www.fas.usda.gov/data/us-renewable-die...  Demand
# 1  https://www.cmegroup.com/education/articles-an...  Demand
# 2  https://www.reuters.com/markets/commodities/wo...  Demand
# 3  https://www.cmegroup.com/articles/2022/low-car...  Demand
# 4  https://www.fastmarkets.com/insights/uco-price...  Demand
# 5  https://www.gminsights.com/industry-analysis/u...  Demand
#
#                                              keyword  \
# 0  Vegetable oils used in biodiesel production de...
# 1  Vegetable oils used in biodiesel production de...
# 2  Vegetable oils used in biodiesel production de...
# 3  Vegetable oils used in biodiesel production de...
# 4  Vegetable oils used in biodiesel production de...
# 5  Vegetable oils used in biodiesel production de...
#
#                                                title              date  \
# 0                                               <NA>              <NA>
# 1                                               <NA>              <NA>
# 2                                               <NA>              <NA>
# 3  Low carbon fuels drive vegetable oil price vol...       14 Oct 2022
# 4  UCO prices reach two-year high in 2024, increa...  January 14, 2025
# 5                                               <NA>              <NA>
#
#                author                                            content
# 0      Timothy O’Neil  Executive Summary
# During the past few years, t...
# 1                <NA>                                               <NA>
# 2                <NA>                                               <NA>
# 3      By   CME Group  The availability of low carbon fuels, produced...
# 4  Veronika Prykhodko  Fastmarkets’ UCO CIF Amsterdam, Rotterdam, Ant...
# 5                <NA>                                               <NA>

# %%
print(articles_df.loc[articles_df['site'] == 'Fastmarkets', 'content'][4])

# %% [markdown]
# # Validly Parsed Articles

# %%
valid_df = articles_df[(~articles_df['title'].isna()) & (~articles_df['content'].isna())]
valid_df

# %% [markdown]
# # Unable-to-Parse Articles

# %%
invalid_df = articles_df.assign(
    title_scraped=~articles_df['title'].isna(), 
    date_scraped=~articles_df['date'].isna(),
    author_scraped=~articles_df['author'].isna(),
    content_scraped=~articles_df['content'].isna()
) 

invalid_df = invalid_df.loc[
    (invalid_df['title_scraped'] == False) | (invalid_df['content_scraped'] == False), 
    ['site', 'url', 'title_scraped', 'date_scraped', 'author_scraped', 'content_scraped']
]

invalid_df

# %% [markdown]
# # Document Unable-to-Parse Articles

# %%
invalid_df.groupby('site', as_index=False).size().rename(columns={'size': 'count'}).sort_values('count', ascending=False)

# %%
invalid_df.to_excel(excel_writer='.\\data\\info\\failed_site_urls.xlsx', sheet_name='news', index=False, header=True)

# %% [markdown]
# ---

# %% [markdown]
# # Development

# %%
# articles_df = pd.DataFrame({
#     'site': [row.site for row in rows],
#     'url': [row.url for row in rows],
#     'theme': [row.theme for row in rows],
#     'keyword': [row.keyword for row in rows],
#     'title': [row.title if row.title is not None else np.nan for row in rows],
#     'date': [row.date if row.date is not None else np.nan for row in rows],
#     'author': [row.author if row.author is not None else np.nan for row in rows],
#     'content': [row.content if row.content is not None else np.nan for row in rows]
# }).astype({
#     'site': 'string',
#     'url': 'string',
#     'theme': 'string',
#     'keyword': 'string',
#     'title': 'string',
#     'date': 'string',
#     'author': 'string',
#     'content': 'string'
# })

# %%
# config = NewsParserConfig()

# def parse(query: str, selector: Selector) -> List[str]:
#     if '/' in query and 'text()' in query:
#         return selector.xpath(query).getall()
#     elif '/' in query:
#         return selector.xpath(query).css('*::text').getall()
#     elif '::text' in query:
#         return selector.css(query).getall()
#     else:
#         return selector.css(f'{query} *::text').getall()

# def piecewise_parse(query: List[str], selector: Selector) -> List[str]: 
#     subqueries = [parse(subquery, selector) for subquery in query]
#     return reduce(lambda x, y: x + y, subqueries)

# rows = []

# for search in articles:
    
#     try:
#         instruction = config.get_instruction(search.article.site)
        
#         if not isinstance(instruction, dict):
#             raise TypeError
#         if not config.instruction_in_scope(search.article.site):
#             raise AttributeError
#         if Schema.TITLE not in instruction:
#             title = None
#         if Schema.DATE not in instruction:
#             date = None 
#         if Schema.AUTHOR not in instruction:
#             author = None 
#         if Schema.CONTENT not in instruction:
#             content = None

#         selector = Selector(text=search.article.html_content)

#         for column, query in instruction.items():

#             if isinstance(query, str):
#                 if column == Schema.TITLE:
#                     title_value = parse(query, selector) 
#                     title = title_value[0].strip() if title_value != [] else None
#                 elif column == Schema.DATE:
#                     date_value = parse(query, selector) 
#                     date = date_value[0].strip() if date_value != [] else None
#                 elif column == Schema.AUTHOR:
#                     author_value = parse(query, selector) 
#                     author = author_value[0].strip() if author_value != [] else None
#                 else:
#                     content_values = parse(query, selector) 
#                     content = '\n'.join([text.strip() for text in content_values]).strip() if content_values != [] else None
#             else:
#                 if column == Schema.TITLE:
#                     title_values = piecewise_parse(query, selector) 
#                     title = '\n'.join([text.strip() for text in title_values]).strip() if title_values != [] else None
#                 elif column == Schema.DATE:
#                     date_values = piecewise_parse(query, selector) 
#                     date = '\n'.join([text.strip() for text in date_values]).strip() if date_values != [] else None
#                 elif column == Schema.AUTHOR:
#                     author_values = piecewise_parse(query, selector) 
#                     author = '\n'.join([text.strip() for text in author_values]).strip() if author_values != [] else None
#                 else:
#                     content_values = piecewise_parse(query, selector) 
#                     content = '\n'.join([text.strip() for text in content_values]).strip() if content_values != [] else None

#         row = Row(title, date, author, search.article.site, search.article.url, search.theme, search.keyword, content)
#         rows.append(row)
#     except KeyError or TypeError or AttributeError:
#         # Cannot find the news site in parser config
#         row = Row(None, None, None, search.article.site, search.article.url, search.theme, search.keyword, None)
#         rows.append(row)
